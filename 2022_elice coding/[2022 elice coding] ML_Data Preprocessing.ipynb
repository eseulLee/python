# %% [markdown]
# ### 💡 데이터 전처리의 역할
# 1. 머신러닝의 입력 형태로 **데이터 변환 (특성 엔지니어링)**
# 2. 결측값 및 이상치를 처리하여 **데이터 정제**
# 3. 학습용 및 평가용 **데이터 분리**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📌 범주형 데이터 전처리
